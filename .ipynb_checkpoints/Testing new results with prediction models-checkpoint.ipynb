# %%
import pandas as pd
import numpy as np
import math

# %%
# Find 3 countries with the biggest CO2 overall emissions

df = pd.read_csv('andmed.csv')

# %%
biggest_emissions = {}
countries = set(df['Country Name']
                
                
                
# country_emissions = df[df['Country Name'] == 'Albania']['CO2 emissions (metric tons per capita) [EN.ATM.CO2E.PC]']
# avg(country_emissions)
# Out:
#   File "<ipython-input-44-38dc12eff936>", line 8
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
emissions = {}
countries = set(df['Country Name'])

for country in countries:
    if country != 'World':
        years = df[df['Country Name'] == country]['CO2 emissions (metric tons per capita) [EN.ATM.CO2E.PC]']
        if len(years) != np.nan and len(years) > 0:
            average = sum(years) / len(years)    
            if not math.isnan(average):
                emissions[country] = average
            

sorted(emissions, key=emissions.get)
# emissions
# Out:
# ['Burundi',
#  'Chad',
#  'Ethiopia',
#  'Central African Republic',
#  'Rwanda',
#  'Mali',
#  'Uganda',
#  'Niger',
#  'Congo, Dem. Rep.',
#  'Somalia',
#  'Burkina Faso',
#  'Malawi',
#  'Nepal',
#  'Madagascar',
#  'Tanzania',
#  'Sierra Leone',
#  'Mozambique',
#  'Cambodia',
#  'Guinea-Bissau',
#  'Haiti',
#  'Afghanistan',
#  'Comoros',
#  'Least developed countries: UN classification',
#  'Myanmar',
#  'Guinea',
#  'Heavily indebted poor countries (HIPC)',
#  'Gambia, The',
#  'Bangladesh',
#  'Togo',
#  'Benin',
#  'Lao PDR',
#  'IDA only',
#  'Cameroon',
#  'Kenya',
#  'Ghana',
#  'Solomon Islands',
#  'Zambia',
#  'Sao Tome and Principe',
#  'Liberia',
#  'Sri Lanka',
#  'Bhutan',
#  'Pre-demographic dividend',
#  'Kiribati',
#  'Senegal',
#  'Vanuatu',
#  'IDA total',
#  "Cote d'Ivoire",
#  'Congo, Rep.',
#  'Cabo Verde',
#  'Yemen, Rep.',
#  'Papua New Guinea',
#  'Mauritania',
#  'Low income',
#  'Paraguay',
#  'Pakistan',
#  'Nigeria',
#  'Guatemala',
#  'Nicaragua',
#  'Djibouti',
#  'Honduras',
#  'Samoa',
#  'El Salvador',
#  'Angola',
#  'South Asia',
#  'South Asia (IDA & IBRD)',
#  'Vietnam',
#  'Tonga',
#  'Philippines',
#  'India',
#  'Eswatini',
#  'Sub-Saharan Africa (excluding high income)',
#  'Sub-Saharan Africa',
#  'Sub-Saharan Africa (IDA & IBRD countries)',
#  'IDA blend',
#  'Fragile and conflict affected situations',
#  'Lower middle income',
#  'Pacific island small states',
#  'Indonesia',
#  'Bolivia',
#  'Morocco',
#  'St. Vincent and the Grenadines',
#  'Fiji',
#  'Dominica',
#  'Zimbabwe',
#  'Costa Rica',
#  'Peru',
#  'Grenada',
#  'Belize',
#  'St. Lucia',
#  'Early-demographic dividend',
#  'Egypt, Arab Rep.',
#  'Colombia',
#  'Brazil',
#  'Dominican Republic',
#  'Mauritius',
#  'Albania',
#  'Uruguay',
#  'Tunisia',
#  'Ecuador',
#  'Panama',
#  'Guyana',
#  'Thailand',
#  'Latin America & Caribbean (excluding high income)',
#  'French Polynesia',
#  'Latin America & the Caribbean (IDA & IBRD countries)',
#  'Latin America & Caribbean',
#  'Low & middle income',
#  'Syrian Arab Republic',
#  'East Asia & Pacific (IDA & IBRD countries)',
#  'East Asia & Pacific (excluding high income)',
#  'Jordan',
#  'IDA & IBRD total',
#  'Macao SAR, China',
#  'Cuba',
#  'St. Kitts and Nevis',
#  'Middle income',
#  'Middle East & North Africa (excluding high income)',
#  'Middle East & North Africa (IDA & IBRD countries)',
#  'Turkey',
#  'Algeria',
#  'Equatorial Guinea',
#  'Chile',
#  'China',
#  'IBRD only',
#  'Lebanon',
#  'Jamaica',
#  'East Asia & Pacific',
#  'Iraq',
#  'Arab World',
#  'Barbados',
#  'Seychelles',
#  'Mexico',
#  'Argentina',
#  'Upper middle income',
#  'Portugal',
#  'Middle East & North Africa',
#  'Malaysia',
#  'Late-demographic dividend',
#  'Suriname',
#  'Mongolia',
#  'Korea, Dem. People’s Rep.',
#  'Hong Kong SAR, China',
#  'Malta',
#  'British Virgin Islands',
#  'Other small states',
#  'Antigua and Barbuda',
#  'Iran, Islamic Rep.',
#  'Gabon',
#  'Small states',
#  'Cyprus',
#  'Switzerland',
#  'Spain',
#  'Venezuela, RB',
#  'Romania',
#  'Hungary',
#  'Greece',
#  'Caribbean small states',
#  'Korea, Rep.',
#  'Sweden',
#  'New Zealand',
#  'Iceland',
#  'Bulgaria',
#  'Israel',
#  'Gibraltar',
#  'Austria',
#  'European Union',
#  'Libya',
#  'Bermuda',
#  'Central Europe and the Baltics',
#  'Ireland',
#  'South Africa',
#  'Japan',
#  'Oman',
#  'Norway',
#  'Greenland',
#  'Cayman Islands',
#  'United Kingdom',
#  'Europe & Central Asia',
#  'Poland',
#  'Denmark',
#  'OECD members',
#  'Finland',
#  'Nauru',
#  'Netherlands',
#  'Belgium',
#  'Europe & Central Asia (IDA & IBRD countries)',
#  'Singapore',
#  'High income',
#  'Post-demographic dividend',
#  'Faroe Islands',
#  'Europe & Central Asia (excluding high income)',
#  'Palau',
#  'New Caledonia',
#  'Bahamas, The',
#  'Saudi Arabia',
#  'Australia',
#  'Canada',
#  'Russian Federation',
#  'North America',
#  'United States',
#  'Trinidad and Tobago',
#  'Bahrain',
#  'Brunei Darussalam',
#  'Luxembourg',
#  'United Arab Emirates',
#  'Qatar',
#  'Aruba']
